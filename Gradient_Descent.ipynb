# %% [markdown]
# ## ***BATCH GD***

# %%
from sklearn.linear_model import SGDRegressor
batch_model = SGDRegressor(
    max_iter = 1000,
    eta0=0.1,
    learning_rate='constant',
    shuffle=False,
    random_state=42
)

#batch_model.fit(X_train, y_train)
#y_pred=batch_model.predict(X_test)

# %% [markdown]
# ## ***STOCHESTIC GB***

# %%
from sklearn.linear_model import SGDRegressor
batch_model = SGDRegressor(
    max_iter = 1000,
    eta0=0.1,
    learning_rate='constant',
    shuffle=True,
    random_state=42
)

# %% [markdown]
# ### ***MINI BATCH***

# %%
from sklearn.linear_model import SGDRegressor
mini_batch=SGDRegressor(
    max_iter = 1,
    eta0=0.1,
    learning_rate='constant',
    random_state=42
)
batch_size =2

#for epoch in range(1000):
 # for i in range(0,len(x_train),batch_size):
  #  x_batch = x_train[i:i+batch_size]
   # y_batch = y_train[i:i+batch_size]

    #mini_batch.partial_fit(x_batch,y_batch)
